# %%
# Re-import necessary libraries since execution state was reset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Number of time steps
time_steps = 50000

# Define the nodes (sensors) for 30 nodes
nodes = [f'node{i}' for i in range(1, 31)]

# Mean temperature for all nodes
z_mean = 20.0

# Define amplitude for all nodes
A_i = 5

# Initialize the DataFrame
data = {node: np.zeros(time_steps) for node in nodes}
data['SN'] = np.arange(time_steps)

# Generate temperature data for nodes based on categories
for node in nodes:
    node_id = int(node.replace('node', ''))  # Extract numeric ID
    
    # Assign parameters based on category
    if 1 <= node_id <= 10:  # Category A
        P_i = 500
        sigma_i = 0.1
    elif 11 <= node_id <= 20:  # Category B
        P_i = 400
        sigma_i = 0.2
    elif 21 <= node_id <= 30:  # Category C
        P_i = 300
        sigma_i = 0.3

    # Generate the temperature using the given equation
    temperature = z_mean + A_i * np.sin((2 * np.pi * np.arange(time_steps)) / P_i) + np.random.normal(loc=0, scale=sigma_i, size=time_steps)
    data[node] = temperature  # Assign the generated temperature to the node

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to CSV
csv_filename = "synthetic_scenario_30_nodes_2.csv"
df.to_csv(csv_filename, index=False)

# Plot to visualize the changes
plt.figure(figsize=(14, 7))
for node in ['node1', 'node5', 'node10', 'node15', 'node20', 'node25', 'node30']:  # Selecting a few nodes from each category
    plt.plot(df['SN'][:1000], df[node][:1000], label=node)  # Plot first 1000 time steps for clarity

plt.xlabel('Time Steps', fontsize=14)
plt.ylabel('Temperature (°C)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Temperature Dynamics of Sensor Nodes', fontsize=16)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), fontsize=12, ncol=3)
plt.grid(True)
plt.show()

# Provide the CSV file for download
csv_filename

# %%
# Re-import necessary libraries since execution state was reset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Number of time steps
time_steps = 50000

# Define the nodes (sensors) for 30 nodes
nodes = [f'node{i}' for i in range(1, 31)]

# Mean temperature for all nodes
z_mean = 20.0

# Define amplitude for all nodes
A_i = 10

# Initialize the DataFrame
data = {node: np.zeros(time_steps) for node in nodes}
data['SN'] = np.arange(time_steps)

# Generate temperature data for nodes based on categories
for node in nodes:
    node_id = int(node.replace('node', ''))  # Extract numeric ID
    
    # Assign parameters based on category
    if 1 <= node_id <= 10:  # Category A
        P_i = 500
        sigma_i = 0.1
    elif 11 <= node_id <= 20:  # Category B
        P_i = 400
        sigma_i = 0.2
    elif 21 <= node_id <= 30:  # Category C
        P_i = 300
        sigma_i = 0.3

    # Generate the temperature using the given equation
    temperature = z_mean + A_i * np.sin((2 * np.pi * np.arange(time_steps)) / P_i) + np.random.normal(loc=0, scale=sigma_i, size=time_steps)
    data[node] = temperature  # Assign the generated temperature to the node

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to CSV
csv_filename = "temp_state.csv"
df.to_csv(csv_filename, index=False)

# Plot to visualize the changes
plt.figure(figsize=(14, 7))
for node in ['node1', 'node5', 'node10', 'node15', 'node20', 'node25', 'node30']:  # Selecting a few nodes from each category
    plt.plot(df['SN'][:1000], df[node][:1000], label=node)  # Plot first 1000 time steps for clarity

plt.xlabel('Time Steps', fontsize=14)
plt.ylabel('Temperature (°C)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Temperature Dynamics of Sensor Nodes', fontsize=16)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), fontsize=12, ncol=3)
plt.grid(True)
plt.show()

# Provide the CSV file for download
csv_filename
# Out:
# 'temp_state.csv'

# %%
# Re-import necessary libraries since execution state was reset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Number of time steps
time_steps = 50000

# Define the nodes (sensors) for 30 nodes
nodes = [f'node{i}' for i in range(1, 31)]

# Mean temperature for all nodes
z_mean = 20.0

# Define amplitude for all nodes
A_i = 10

# Initialize the DataFrame
data = {node: np.zeros(time_steps) for node in nodes}
data['SN'] = np.arange(time_steps)

# Generate temperature data for nodes based on categories
for node in nodes:
    node_id = int(node.replace('node', ''))  # Extract numeric ID
    
    # Assign parameters based on category
    if 1 <= node_id <= 10:  # Category A
        P_i = 500
        sigma_i = 0.1
    elif 11 <= node_id <= 20:  # Category B
        P_i = 1000
        sigma_i = 0.1
    elif 21 <= node_id <= 30:  # Category C
        P_i = 1500
        sigma_i = 0.1

    # Generate the temperature using the given equation
    temperature = z_mean + A_i * np.sin((2 * np.pi * np.arange(time_steps)) / P_i) + np.random.normal(loc=0, scale=sigma_i, size=time_steps)
    data[node] = temperature  # Assign the generated temperature to the node

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to CSV
csv_filename = "temp_state_2.csv"
df.to_csv(csv_filename, index=False)

# Plot to visualize the changes
plt.figure(figsize=(14, 7))
for node in ['node1', 'node5', 'node10', 'node15', 'node20', 'node25', 'node30']:  # Selecting a few nodes from each category
    plt.plot(df['SN'][:1000], df[node][:1000], label=node)  # Plot first 1000 time steps for clarity

plt.xlabel('Time Steps', fontsize=14)
plt.ylabel('Temperature (°C)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Temperature Dynamics of Sensor Nodes', fontsize=16)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), fontsize=12, ncol=3)
plt.grid(True)
plt.show()

# Provide the CSV file for download
csv_filename
# Out:
# 'temp_state_2.csv'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Parameters
time_steps = 50000
num_nodes = 50
num_categories = 10  # We now want 10 categories
nodes = [f'node{i}' for i in range(1, num_nodes + 1)]
z_mean = 20.0  # Mean temperature
A_i = 10       # Amplitude for all nodes

# Initialize the DataFrame
data = {node: np.zeros(time_steps) for node in nodes}
data['SN'] = np.arange(time_steps)

# Divide nodes into 10 categories and generate staggered periods and noise
nodes_per_category = num_nodes // num_categories
for i, node in enumerate(nodes):
    category = i // nodes_per_category
    # Define staggered period ranges for each category to diversify patterns
    P_low = 300 + category * 150
    P_high = P_low + 100
    P_i = np.random.randint(P_low, P_high)
    sigma_i = 0.1 + (category * 0.01)  # Slight increase in noise per category

    # Generate the temperature using the sine equation with noise
    temperature = z_mean + A_i * np.sin((2 * np.pi * np.arange(time_steps)) / P_i) + \
                  np.random.normal(loc=0, scale=sigma_i, size=time_steps)
    data[node] = temperature

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to CSV
csv_filename = "push_pull_data_event_test.csv"
df.to_csv(csv_filename, index=False)

# Plot to visualize the changes for a few example nodes
plt.figure(figsize=(14, 7))
example_nodes = ['node1', 'node10', 'node20', 'node30', 'node40', 'node50']
for node in example_nodes:
    plt.plot(df['SN'][:1000], df[node][:1000], label=node)  # Plot first 1000 time steps for clarity

plt.xlabel('Time Steps', fontsize=14)
plt.ylabel('Temperature (°C)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Temperature Dynamics of 50 Nodes in 10 Categories', fontsize=16)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), fontsize=12, ncol=3)
plt.grid(True)
plt.show()

csv_filename
# Out:
# 'push_pull_data_event_test.csv'
